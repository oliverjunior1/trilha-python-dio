# %% [markdown]
# <a href="https://colab.research.google.com/github/oliverjunior1/trilha-python-dio/blob/main/Python_para_analise_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

california_housing = pd.read_csv('sample_data/california_housing_train.csv')
california_housing.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-62431042> in <cell line: 0>()
# ----> 1 x.shape()
#
# NameError: name 'x' is not defined

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
import pandas as pd

x = pd.read_csv("/content/sample_data/organizations_gdp_hist.csv", sep=';')
x = x.rename(columns={'country_code':'codigo_de_país', 'organization_name':'nome_organizacional', 'region':'região','income_group':'grupo_de_renda', 'year':'ano', })
x
# Out:
#      codigo_de_país nome_organizacional  \
# 0               AFE                 NaN
# 1               AFE                 NaN
# 2               AFE                 NaN
# 3               AFE                 NaN
# 4               AFE                 NaN
# ...             ...                 ...
# 3259            XKX              KOSOVO
# 3260            XKX              KOSOVO
# 3261            XKX              KOSOVO
# 3262            XKX              KOSOVO
# 3263            XKX              KOSOVO
#
#                                                região        grupo_de_renda  \
# 0                                             NO DATA             AGREGADOS
# 1                                             NO DATA             AGREGADOS
# 2                                             NO DATA             AGREGADOS
# 3                                             NO DATA             AGREGADOS
# 4                                             NO DATA             AGREGADOS
# ...

# %%
x.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-1748661272> in <cell line: 0>()
# ----> 1 x.columns
#
# NameError: name 'x' is not defined

# %%
x.dtypes
# Out:
# codigo_de_país          object
# nome_organizacional     object
# região                  object
# grupo_de_renda          object
# ano                      int64
# total_gdp              float64
# total_gdp_million      float64
# gdp_variation          float64
# dtype: object

# %%
x.tail()
# Out:
#      codigo_de_país nome_organizacional  \
# 3259            XKX              KOSOVO
# 3260            XKX              KOSOVO
# 3261            XKX              KOSOVO
# 3262            XKX              KOSOVO
# 3263            XKX              KOSOVO
#
#                                                região        grupo_de_renda  \
# 3259  EUROPA Y ASIA CENTRAL (EXCLUIDO ALTOS INGRESOS)  INGRESO MEDIANO ALTO
# 3260  EUROPA Y ASIA CENTRAL (EXCLUIDO ALTOS INGRESOS)  INGRESO MEDIANO ALTO
# 3261  EUROPA Y ASIA CENTRAL (EXCLUIDO ALTOS INGRESOS)  INGRESO MEDIANO ALTO
# 3262  EUROPA Y ASIA CENTRAL (EXCLUIDO ALTOS INGRESOS)  INGRESO MEDIANO ALTO
# 3263  EUROPA Y ASIA CENTRAL (EXCLUIDO ALTOS INGRESOS)  INGRESO MEDIANO ALTO
#
#        ano     total_gdp  total_gdp_million  gdp_variation
# 3259  2019  7.899738e+09        7899.737577       4.756801
# 3260  2020  7.717145e+09        7717.145218      -5.340275
# 3261  2021  9.413404e+09        9413.403724      10.745656
# ...

# %%
x.tail(15)
# Out:
#      codigo_de_país nome_organizacional  \
# 3249            XKX              KOSOVO
# 3250            XKX              KOSOVO
# 3251            XKX              KOSOVO
# 3252            XKX              KOSOVO
# 3253            XKX              KOSOVO
# 3254            XKX              KOSOVO
# 3255            XKX              KOSOVO
# 3256            XKX              KOSOVO
# 3257            XKX              KOSOVO
# 3258            XKX              KOSOVO
# 3259            XKX              KOSOVO
# 3260            XKX              KOSOVO
# 3261            XKX              KOSOVO
# 3262            XKX              KOSOVO
# 3263            XKX              KOSOVO
#
#                                                região        grupo_de_renda  \
# 3249  EUROPA Y ASIA CENTRAL (EXCLUIDO ALTOS INGRESOS)  INGRESO MEDIANO ALTO
# 3250  EUROPA Y ASIA CENTRAL (EXCLUIDO ALTOS INGRESOS)  INGRESO MEDIANO ALTO
# 3251  EUROPA Y ASIA CENTRAL (EXCLUIDO ALTOS INGRESOS)  INGRESO MEDIANO ALTO
# ...

# %%
x.describe()
# Out:
#                ano     total_gdp  total_gdp_million  gdp_variation
# count  3264.000000  3.264000e+03       3.264000e+03    3264.000000
# mean   1991.500000  4.542641e+12       4.542641e+06       3.440956
# std      18.475784  1.066152e+13       1.066152e+07       3.242767
# min    1960.000000  0.000000e+00       0.000000e+00     -13.328285
# 25%    1975.750000  9.651819e+10       9.651819e+04       1.233666
# 50%    1991.500000  5.517042e+11       5.517042e+05       3.570205
# 75%    2007.250000  2.860624e+12       2.860624e+06       5.439760
# max    2023.000000  1.061717e+14       1.061717e+08      23.067604

# %%
x['região'].unique()
# Out:
# array(['NO DATA', 'EUROPA Y ASIA CENTRAL (EXCLUIDO ALTOS INGRESOS)'],
#       dtype=object)

# %%
x.head(25)
# Out:
#    codigo_de_país nome_organizacional   região grupo_de_renda   ano  \
# 0             AFE                 NaN  NO DATA      AGREGADOS  1960
# 1             AFE                 NaN  NO DATA      AGREGADOS  1961
# 2             AFE                 NaN  NO DATA      AGREGADOS  1962
# 3             AFE                 NaN  NO DATA      AGREGADOS  1963
# 4             AFE                 NaN  NO DATA      AGREGADOS  1964
# 5             AFE                 NaN  NO DATA      AGREGADOS  1965
# 6             AFE                 NaN  NO DATA      AGREGADOS  1966
# 7             AFE                 NaN  NO DATA      AGREGADOS  1967
# 8             AFE                 NaN  NO DATA      AGREGADOS  1968
# 9             AFE                 NaN  NO DATA      AGREGADOS  1969
# 10            AFE                 NaN  NO DATA      AGREGADOS  1970
# 11            AFE                 NaN  NO DATA      AGREGADOS  1971
# 12            AFE                 NaN  NO DATA      AGREGADOS  1972
# ...
